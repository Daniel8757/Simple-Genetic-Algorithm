# %%
import pandas as pd
import RealValueGA
model = RealValueGA.LogisticalRegression()

# %%
x = [[1], [1], [1], [5], [5], [5]]
y = [0, 0, 0, 1, 1, 1]

# %%
model.run(1, x, y)
# Out:
# Population size: 50
# Genome length: 2
# Generation 0: average fitness 0.23476637871795017, best fitness [-0.9757144120006773, 0.807183254134368]
# Generation 1: average fitness 0.24711794969992532, best fitness [-0.9757144120006773, 0.807183254134368]
# Generation 2: average fitness 0.24753992530039437, best fitness [-0.9757144120006773, 0.807183254134368]
# Generation 3: average fitness 0.2529523590145514, best fitness [-0.9757144120006773, 0.807183254134368]
# Generation 4: average fitness 0.24771810145631903, best fitness [-0.9757144120006773, 0.807183254134368]
# Generation 5: average fitness 0.2604921460097505, best fitness [-0.9757144120006773, 0.807183254134368]
# Generation 6: average fitness 0.264363959803563, best fitness [-0.9187163426318605, 0.35642951713743076]
# Generation 7: average fitness 0.27611629563181084, best fitness [-0.9757144120006773, 0.35642951713743076]
# ...
