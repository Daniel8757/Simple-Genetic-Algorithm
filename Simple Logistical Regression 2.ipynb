# %%
import pandas as pd
import RealValueGA
model = RealValueGA.LogisticalRegression()

# %%
x = [[0, 0], [1, 2], [2, 1], [10, 5], [5, 10], [10, 10]]
y = [0, 0, 0, 1, 1, 1]

# %%
model.run(1, x, y)
# Out:
# Population size: 50
# Genome length: 2
# Generation 0: average fitness 0.21845742834966347, best fitness [-0.8222428200789016, -0.16515044007311208]
# Generation 1: average fitness 0.23455651858971407, best fitness [-0.8222428200789016, -0.16515044007311208]
# Generation 2: average fitness 0.2401129263449847, best fitness [-0.7628599275070642, -0.07474498146063491]
# Generation 3: average fitness 0.24460259662303696, best fitness [-0.7975485211574704, -0.07474498146063491]
# Generation 4: average fitness 0.2502773743623765, best fitness [-0.7904865308645255, -0.07474498146063491]
# Generation 5: average fitness 0.251667854034384, best fitness [-0.7904865308645255, -0.07474498146063491]
# Generation 6: average fitness 0.25061731997007664, best fitness [-0.7975485211574704, 0.09995432143427685]
# Generation 7: average fitness 0.2546922945640253, best fitness [-0.9071311001492859, 0.09995432143427685]
# ...
